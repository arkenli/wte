# %%
import pandas as pd
import numpy as np

# %%
df_epi_r=pd.read_csv('data/epirecipes/epi_r.csv')
epi_r.tail()
# Out:
#                                              title  rating  calories  protein  \
# 20047                              Parmesan Puffs    3.125      28.0      2.0
# 20048              Artichoke and Parmesan Risotto    4.375     671.0     22.0
# 20049                       Turkey Cream Puff Pie    4.375     563.0     31.0
# 20050     Snapper on Angel Hair with Citrus Cream    4.375     631.0     45.0
# 20051  Baked Ham with Marmalade-Horseradish Glaze    4.375     560.0     73.0
#
#         fat  sodium  #cakeweek  #wasteless  22-minute meals  \
# 20047   2.0    64.0        0.0         0.0              0.0
# 20048  28.0   583.0        0.0         0.0              0.0
# 20049  38.0   652.0        0.0         0.0              0.0
# 20050  24.0   517.0        0.0         0.0              0.0
# 20051  10.0  3698.0        0.0         0.0              0.0
#
#        3-ingredient recipes   ...    yellow squash  yogurt  yonkers  yuca  \
# ...

# %%
json_f_recipe=pd.read_json('data/epirecipes/full_format_recipes.json')

# %%
json_f_recipe.keys()
# Out:
# Index(['calories', 'categories', 'date', 'desc', 'directions', 'fat',
#        'ingredients', 'protein', 'rating', 'sodium', 'title'],
#       dtype='object')

# %%
json_f_recipe[''][20053]
# Out:
# 'Chicken (Pot) Handpies '

# %%
df_r=pd.read_csv('data/food-com-recipes-and-user-interactions/RAW_recipes.csv')
df_r.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# ...

# %%
df_r['n_ingredients'][0]
# Out:
# 7

# %% [markdown]
# 可以用原料来进行相似度的分析
#
# 推荐系统也可以根据原料来做一部分
#
# like,also like
#
# 另外两个数据集之间需要的联系（第一个没有用户的评价所以没法知道其它人认为哪个好哪个不好）
#
# 主料，调料

# %%
s="'"+s+"'"
s
# Out:
# "'wintersquash','mexicanseasoning','mixedspice','honey','butter','oliveoil','salt'"

# %%
s=s.split(',')

# %%
pp_users=pd.read_csv('data/food-com-recipes-and-user-interactions/PP_users.csv')

# %%
pp_users.head()
# Out:
#    u                                         techniques  \
# 0  0  [8, 0, 0, 5, 6, 0, 0, 1, 0, 9, 1, 0, 0, 0, 1, ...
# 1  1  [11, 0, 0, 2, 12, 0, 0, 0, 0, 14, 5, 0, 0, 0, ...
# 2  2  [13, 0, 0, 7, 5, 0, 1, 2, 1, 11, 0, 1, 0, 0, 1...
# 3  3  [498, 13, 4, 218, 376, 3, 2, 33, 16, 591, 10, ...
# 4  4  [161, 1, 1, 86, 93, 0, 0, 11, 2, 141, 0, 16, 0...
#
#                                                items  n_items  \
# 0  [1118, 27680, 32541, 137353, 16428, 28815, 658...       31
# 1  [122140, 77036, 156817, 76957, 68818, 155600, ...       39
# 2  [168054, 87218, 35731, 1, 20475, 9039, 124834,...       27
# 3  [163193, 156352, 102888, 19914, 169438, 55772,...     1513
# 4  [72857, 38652, 160427, 55772, 119999, 141777, ...      376
#
#                                              ratings  n_ratings
# 0  [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 4.0, 4.0, ...         31
# 1  [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, ...         39
# ...
